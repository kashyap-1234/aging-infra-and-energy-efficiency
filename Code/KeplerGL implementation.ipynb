# %%
# !pip install keplergl pandas
# Out:
# Requirement already satisfied: keplergl in c:\users\hp\anaconda3\lib\site-packages (0.3.2)
# Requirement already satisfied: pandas in c:\users\hp\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: ipywidgets<8,>=7.0.0 in c:\users\hp\anaconda3\lib\site-packages (from keplergl) (7.8.5)
# Requirement already satisfied: traittypes>=0.2.1 in c:\users\hp\anaconda3\lib\site-packages (from keplergl) (0.2.1)
# Requirement already satisfied: geopandas>=0.5.0 in c:\users\hp\anaconda3\lib\site-packages (from keplergl) (1.0.1)
# Requirement already satisfied: Shapely>=1.6.4.post2 in c:\users\hp\anaconda3\lib\site-packages (from keplergl) (2.0.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\hp\anaconda3\lib\site-packages (from geopandas>=0.5.0->keplergl) (0.10.0)
# Requirement already satisfied: packaging in c:\users\hp\anaconda3\lib\site-packages (from geopandas>=0.5.0->keplergl) (23.0)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\hp\anaconda3\lib\site-packages (from geopandas>=0.5.0->keplergl) (3.7.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\hp\anaconda3\lib\site-packages (from ipywidgets<8,>=7.0.0->keplergl) (0.2.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\hp\anaconda3\lib\site-packages (from ipywidgets<8,>=7.0.0->keplergl) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\hp\anaconda3\lib\site-packages (from ipywidgets<8,>=7.0.0->keplergl) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.10 in c:\users\hp\anaconda3\lib\site-packages (from ipywidgets<8,>=7.0.0->keplergl) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\hp\anaconda3\lib\site-packages (from ipywidgets<8,>=7.0.0->keplergl) (8.12.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\hp\anaconda3\lib\site-packages (from ipywidgets<8,>=7.0.0->keplergl) (1.1.11)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: backcall in c:\users\hp\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.2.0)
# Requirement already satisfied: decorator in c:\users\hp\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\hp\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\hp\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\hp\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\hp\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\hp\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\hp\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.2.0)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.4.6)
# Requirement already satisfied: certifi in c:\users\hp\anaconda3\lib\site-packages (from pyogrio>=0.7.2->geopandas>=0.5.0->keplergl) (2023.7.22)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\hp\anaconda3\lib\site-packages (from widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (6.5.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\hp\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.8.3)
# Requirement already satisfied: jinja2 in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (3.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (6.3.2)
# Requirement already satisfied: pyzmq>=17 in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (23.2.0)
# Requirement already satisfied: argon2-cffi in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (21.3.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (5.3.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (7.4.9)
# Requirement already satisfied: nbformat in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (5.7.0)
# Requirement already satisfied: nbconvert>=5 in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (1.5.6)
# Requirement already satisfied: ipykernel in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (6.19.2)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (0.17.1)
# Requirement already satisfied: prometheus-client in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (0.5.5)
# Requirement already satisfied: wcwidth in c:\users\hp\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.2.5)
# Requirement already satisfied: executing in c:\users\hp\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\hp\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\hp\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.2.2)
# Requirement already satisfied: entrypoints in c:\users\hp\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (2.5.2)
# Requirement already satisfied: pywin32>=300 in c:\users\hp\anaconda3\lib\site-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (305.1)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\hp\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\hp\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (0.2.2)
# Requirement already satisfied: lxml in c:\users\hp\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (4.12.2)
# Requirement already satisfied: bleach in c:\users\hp\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\hp\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\hp\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (1.2.1)
# Requirement already satisfied: fastjsonschema in c:\users\hp\anaconda3\lib\site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\hp\anaconda3\lib\site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (4.17.3)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\hp\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\hp\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (21.2.0)
# Requirement already satisfied: debugpy>=1.0 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (1.6.7)
# Requirement already satisfied: psutil in c:\users\hp\anaconda3\lib\site-packages (from ipykernel->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (5.9.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (0.18.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\hp\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (3.5.0)
# Requirement already satisfied: websocket-client in c:\users\hp\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hp\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (2.4)
# Requirement already satisfied: webencodings in c:\users\hp\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (0.5.1)
# Requirement already satisfied: idna>=2.8 in c:\users\hp\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hp\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\hp\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets<8,>=7.0.0->keplergl) (2.21)

# %%
import pandas as pd
from keplergl import KeplerGl

# Load the initial dataset
file_path = r"D:\A_Kashyap\UIC\Sem-3\Big Data Visualization\Data\Cleaned_Chicago_Energy_Efficiency_Data.csv"
data = pd.read_csv(file_path)

# Initialize Kepler.gl map
kepler_map = KeplerGl(height=800)

# Add the cleaned data to the map
kepler_map.add_data(data=data, name="Chicago Buildings")

# Customize Kepler.gl configuration
config = {
    "version": "v1",
    "config": {
        "visState": {
            "filters": [],
            "layers": [
                # Layer for View 1
                {
                    "id": "view-1-layer",
                    "type": "point",
                    "config": {
                        "dataId": "Chicago Buildings",
                        "label": "Buildings - View 1",
                        "columns": {
                            "lat": "Latitude",
                            "lng": "Longitude"
                        },
                        "isVisible": True,
                        "visConfig": {
                            "radius": 10,
                            "colorRange": {
                                "name": "Global Warming",
                                "type": "sequential",
                                "category": "Uber",
                                "colors": [
                                    "#5A1846",
                                    "#900C3F",
                                    "#C70039",
                                    "#E3611C",
                                    "#F1920E",
                                    "#FFC300"
                                ]
                            },
                            "radiusRange": [5, 20]
                        }
                    },
                    "visualChannels": {
                        "colorField": {"name": "GHG_Emissions", "type": "real"},
                        "sizeField": {"name": "RPS", "type": "real"},
                        "sizeScale": "sqrt"
                    }
                }
            ],
            "interactionConfig": {
                "tooltip": {
                    "enabled": True,
                    "fieldsToShow": {
                        "Chicago Buildings": [
                            {"name": "Address", "format": None},
                            {"name": "GHG_Emissions", "format": None},
                            {"name": "RPS", "format": None},
                            {"name": "ESI", "format": None}
                        ]
                    }
                },
                "brush": {"enabled": False},  # Disable brush interaction
                "geocoder": {"enabled": True},  # Keep geocoder for search
                "coordinate": {"enabled": True}  # Allow coordinate display
            },
            "layerBlending": "normal",
            "splitMaps": [
                {"layers": ["view-1-layer"]}  # Assign first layer to View 1
            ]
        },
        "mapState": {
            "bearing": 0,
            "pitch": 45,
            "latitude": 41.8781,  # Initial center for the map
            "longitude": -87.6298,
            "zoom": 11
        },
        "mapStyle": {"styleType": "dark"}
    },
    "uiState": {
        "readOnly": False,  # Allow adding datasets dynamically
        "mapControls": {
            "visibleLayers": {"show": True},
            "toggle3d": {"show": True},
            "splitMap": {"show": True},
            "mapLegend": {"show": True},
            "mapDraw": {"show": True},
            "mapPanel": {"show": True},
        },
        "customLogoUrl": None,  # Remove "Kepler.gl Jupyter" logo
        "mapTitle": "Custom Energy Efficiency Map"  # Replace the label
    }
}

# Apply the updated configuration
kepler_map.config = config

# Save the map to an HTML file
kepler_map.save_to_html(file_name="Kepler_Chicago_Custom_Datasets.html")
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# Map saved to Kepler_Chicago_Custom_Datasets.html!
# C:\Users\HP\anaconda3\Lib\site-packages\jupyter_client\session.py:718: UserWarning: Message serialization failed with:
# Out of range float values are not JSON compliant
# Supporting this message is deprecated in jupyter-client 7, please make sure your message is JSON-compliant
#   content = self.pack(content)
